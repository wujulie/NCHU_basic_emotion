# %%
"""
調整傾斜臉的主程式
"""

from collections import OrderedDict
import numpy as np
import cv2
from os import listdir, path

from os.path import join, isfile, isdir

FACIAL_LANDMARKS_IDXS = OrderedDict([("mouth", (48, 68)),
                                     ("right_eyebrow", (17, 22)),
                                     ("left_eyebrow", (22, 27)),
                                     ("right_eye", (36, 42)),
                                     ("left_eye", (42, 48)),
                                     ("nose", (27, 36)),
                                     ("jaw", (0, 17))
                                     ])

def shape_to_np(shape, dtype="int"):
    coordinates_list = np.zeros((68, 2), dtype=dtype)
    for i in range(0, 68):
        coordinates_list[i] = (shape.part(i).x, shape.part(i).y)
    return coordinates_list

class FaceAligner:
    def __init__(self, predictor, desiredLeftEye=(0.35, 0.35), desiredFaceWidth=256, desiredFaceHeight=None):

        self.predictor = predictor
        self.desiredLeftEye = desiredLeftEye
        self.desiredFaceWidth = desiredFaceWidth
        self.desiredFaceHeight = desiredFaceHeight

        if self.desiredFaceHeight is None:
            self.desiredFaceHeight = self.desiredFaceWidth

    def align(self, image, gray, rect):

        shape = self.predictor(gray, rect)
        shape = shape_to_np(shape)

        (lStart, lEnd) = FACIAL_LANDMARKS_IDXS["left_eye"]
        (rStart, rEnd) = FACIAL_LANDMARKS_IDXS["right_eye"]
        leftEyePts = shape[lStart:lEnd]
        rightEyePts = shape[rStart:rEnd]

        leftEyeCenter = leftEyePts.mean(axis=0).astype("int")
        rightEyeCenter = rightEyePts.mean(axis=0).astype("int")

        dY = rightEyeCenter[1] - leftEyeCenter[1]
        dX = rightEyeCenter[0] - leftEyeCenter[0]
        angle = np.degrees(np.arctan2(dY, dX)) - 180

        desiredRightEyeX = 1.0 - self.desiredLeftEye[0]

        dist = np.sqrt((dX ** 2) + (dY ** 2))
        desiredDist = (desiredRightEyeX - self.desiredLeftEye[0])
        desiredDist *= self.desiredFaceWidth
        scale = desiredDist / dist

        eyesCenter = ((leftEyeCenter[0] + rightEyeCenter[0]) // 2, (leftEyeCenter[1] + rightEyeCenter[1]) // 2)

        M = cv2.getRotationMatrix2D(eyesCenter, angle, scale) # - angle

        tX = self.desiredFaceWidth * 0.5
        tY = self.desiredFaceHeight * self.desiredLeftEye[1]
        M[0, 2] += (tX - eyesCenter[0])
        M[1, 2] += (tY - eyesCenter[1])

        (w, h) = (self.desiredFaceWidth, self.desiredFaceHeight)
        output = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC)

        return output, angle


import cv2
import dlib
# import glob

predictor_path = "/content/drive/MyDrive/basic_emotion/shape_predictor_68_face_landmarks.dat"
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(predictor_path)
fa = FaceAligner(predictor, desiredFaceWidth=256)

def resize(image, width=None, height=None, inter=cv2.INTER_AREA):
    dim = None
    (h, w) = image.shape[:2]

    if width is None and height is None:
        return image

    if width is None:
        r = height / float(h)
        dim = (int(w * r), height)

    else:
        r = width / float(w)
        dim = (width, int(h * r))

    resized = cv2.resize(image, dim, interpolation=inter)
    return resized

def file_name_list(filepath):
     files = listdir(filepath)
     file_list = []
     for f in files:
         fullpath = join(filepath, f)
         if isdir(fullpath):
             # filename, file_extension = path.splitext(f)
             file_list.append(f)
     return file_list

# %%
import glob
import cv2
import os
import dlib

folders=[]

path = '/content/drive/MyDrive/basic_emotion/JAFFE'
for root, dirs, files in os.walk(path, topdown=False):
    for name in dirs:
        folders.append(name)



for fld in folders:
    index = folders.index(fld)
    print('Loading {} files (Index: {})'.format(fld, index))
    fold = os.path.basename(fld)
    p = os.path.join(path, fold, '*g')
    #p = os.path.join(path, fold, '*.tiff')
    files = glob.glob(p)
    output = []
    count = 0
    for i, fl in enumerate(files):
        single_path = '/content/drive/MyDrive/basic_emotion/cut_result/{}'.format(fld)
        flbase = os.path.basename(fl)
        if not os.path.exists(single_path):
            os.makedirs(single_path)
        img = cv2.imread(fl)
        print(flbase)
        predictor_path = "/content/drive/MyDrive/basic_emotion/shape_predictor_68_face_landmarks.dat"
        detector = dlib.get_frontal_face_detector()
        predictor = dlib.shape_predictor(predictor_path)
        fa = FaceAligner(predictor, desiredFaceWidth=256)
        print(fl)
        try:
            image = resize(img, width=224)
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            rects = detector(gray, 1)

            for rect in rects:

                faceAligned, face_angle = fa.align(image, gray, rect)
                gray_image = cv2.cvtColor(faceAligned, cv2.COLOR_BGR2GRAY)

                #write_name = str(count) + '.jpg'  #將圖片重新命名，從0開始(迴圈的i)
                write_name = str(flbase)
                print(write_name)

                #*src_RGB = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2RGB)
                #*cv2.imwrite(single_path + '\\{}'.format(write_name), src_RGB)

                cv2.imwrite(single_path + '/{}'.format(write_name), gray_image)
                #count += 1

        except:
            pass
# Out:
# Loading 3 files (Index: 0)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/28.jpg
# 28.jpg
# 29.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/29.jpg
# 29.jpg
# 30.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/3/30.jpg
# 30.jpg
# Loading 4 files (Index: 1)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/28.jpg
# 28.jpg
# 29.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/29.jpg
# 29.jpg
# 30.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/4/30.jpg
# 30.jpg
# Loading 1 files (Index: 2)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/1/28.jpg
# 28.jpg
# Loading 2 files (Index: 3)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/28.jpg
# 28.jpg
# 29.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/29.jpg
# 29.jpg
# 30.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/30.jpg
# 30.jpg
# 31.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/2/31.jpg
# 31.jpg
# Loading 0 files (Index: 4)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/28.jpg
# 28.jpg
# 29.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/0/29.jpg
# 29.jpg
# Loading 5 files (Index: 5)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/28.jpg
# 28.jpg
# 29.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/5/29.jpg
# 29.jpg
# Loading 6 files (Index: 6)
# 0.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/0.jpg
# 0.jpg
# 1.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/1.jpg
# 1.jpg
# 2.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/2.jpg
# 2.jpg
# 3.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/3.jpg
# 3.jpg
# 4.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/4.jpg
# 4.jpg
# 5.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/5.jpg
# 5.jpg
# 6.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/6.jpg
# 6.jpg
# 7.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/7.jpg
# 7.jpg
# 8.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/8.jpg
# 8.jpg
# 9.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/9.jpg
# 9.jpg
# 10.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/10.jpg
# 10.jpg
# 11.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/11.jpg
# 11.jpg
# 12.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/12.jpg
# 12.jpg
# 13.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/13.jpg
# 13.jpg
# 14.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/14.jpg
# 14.jpg
# 15.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/15.jpg
# 15.jpg
# 16.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/16.jpg
# 16.jpg
# 17.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/17.jpg
# 17.jpg
# 18.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/18.jpg
# 18.jpg
# 19.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/19.jpg
# 19.jpg
# 20.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/20.jpg
# 20.jpg
# 21.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/21.jpg
# 21.jpg
# 22.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/22.jpg
# 22.jpg
# 23.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/23.jpg
# 23.jpg
# 24.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/24.jpg
# 24.jpg
# 25.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/25.jpg
# 25.jpg
# 26.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/26.jpg
# 26.jpg
# 27.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/27.jpg
# 27.jpg
# 28.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/28.jpg
# 28.jpg
# 29.jpg
# /content/drive/MyDrive/basic_emotion/JAFFE/6/29.jpg
# 29.jpg
